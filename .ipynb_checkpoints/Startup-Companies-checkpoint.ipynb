# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
#Notes for efficienccy:
#shift + tab when cursor is in arguments to bring up its documentation
#ex: pd.DataFrame(Shift+tab here)
#recall: Json == Dictionary
#to know functions of pandas:
dir(pd)
# Out:
# ['BooleanDtype',
#  'Categorical',
#  'CategoricalDtype',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'DatetimeTZDtype',
#  'ExcelFile',
#  'ExcelWriter',
#  'Flags',
#  'Float32Dtype',
#  'Float64Dtype',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int16Dtype',
#  'Int32Dtype',
#  'Int64Dtype',
#  'Int64Index',
#  'Int8Dtype',
#  'Interval',
#  'IntervalDtype',
#  'IntervalIndex',
#  'MultiIndex',
#  'NA',
#  'NaT',
#  'NamedAgg',
#  'Period',
#  'PeriodDtype',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseDtype',
#  'StringDtype',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt16Dtype',
#  'UInt32Dtype',
#  'UInt64Dtype',
#  'UInt64Index',
#  'UInt8Dtype',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__getattr__',
#  '__git_version__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_config',
#  '_hashtable',
#  '_is_numpy_dev',
#  '_lib',
#  '_libs',
#  '_np_version_under1p18',
#  '_testing',
#  '_tslib',
#  '_typing',
#  '_version',
#  'api',
#  'array',
#  'arrays',
#  'bdate_range',
#  'compat',
#  'concat',
#  'core',
#  'crosstab',
#  'cut',
#  'date_range',
#  'describe_option',
#  'errors',
#  'eval',
#  'factorize',
#  'get_dummies',
#  'get_option',
#  'infer_freq',
#  'interval_range',
#  'io',
#  'isna',
#  'isnull',
#  'json_normalize',
#  'lreshape',
#  'melt',
#  'merge',
#  'merge_asof',
#  'merge_ordered',
#  'notna',
#  'notnull',
#  'offsets',
#  'option_context',
#  'options',
#  'pandas',
#  'period_range',
#  'pivot',
#  'pivot_table',
#  'plotting',
#  'qcut',
#  'read_clipboard',
#  'read_csv',
#  'read_excel',
#  'read_feather',
#  'read_fwf',
#  'read_gbq',
#  'read_hdf',
#  'read_html',
#  'read_json',
#  'read_orc',
#  'read_parquet',
#  'read_pickle',
#  'read_sas',
#  'read_spss',
#  'read_sql',
#  'read_sql_query',
#  'read_sql_table',
#  'read_stata',
#  'read_table',
#  'read_xml',
#  'reset_option',
#  'set_eng_float_format',
#  'set_option',
#  'show_versions',
#  'test',
#  'testing',
#  'timedelta_range',
#  'to_datetime',
#  'to_numeric',
#  'to_pickle',
#  'to_timedelta',
#  'tseries',
#  'unique',
#  'util',
#  'value_counts',
#  'wide_to_long']

# %%
# Setup matplotlib to plot inline (within the notebook)
# %matplotlib inline
# Import the pyplot module of Matplotlib as plt
import matplotlib.pyplot as plt
# Import pandas under the abbreviation 'pd'
import pandas as pd
# Import NumPy under the abbreviation 'np'
import numpy as np

# %%
# Import the heart disease dataset and save it to a variable
# using pandas and read_csv()
# Alternatively: You can directly pass the URL of a csv to read_csv()
acquis = pd.read_csv("datasets/startups/acquisitions.csv")
additions = pd.read_csv("datasets/startups/additions.csv")
companies = pd.read_csv("datasets/startups/companies.csv")
invests = pd.read_csv("datasets/startups/investments.csv")
rounds = pd.read_csv("datasets/startups/rounds.csv")
dfAll = [acquis, additions, companies, invests, rounds]

# %%
#shapes (rows x cols) of each dataset
for ele in dfAll:
    print(ele.shape)
# Out:
# (18969, 18)
# (2213, 4)
# (66368, 14)
# (168647, 18)
# (114949, 12)

# %%
import pandas as pd
def dfsCols(pad, csvNames, *args):
    """
    Takes dataframes and returns a dataframe (df) with each column having a df's
    column names. The "pad" is to make sure all lists of columns have 
    the same length padded out with "pad"
    Example
    pad = "XX", csvNames = ["cars", "planes"]
    args = [carsDF, planesDF]
    returned data frame:
            cars            planes
    0       numOfWheels     numOfWings
    1       manufacturer    manufacturer
    2       make            XX
    """
    cols = []
    maxArrayLen = 0
    for i, ele in enumerate(args):
        cols.append(ele.columns.tolist())
        maxArrayLen = max(maxArrayLen, len(cols[i]))
    
    dictCsvs = {}
    for i, ele in enumerate(args):
        cols[i] += [pad] * (maxArrayLen - len(cols[i])) #padding the lists to make them have equal lengths 
        dictCsvs.update({csvNames[i] : cols[i]})

    return pd.DataFrame(dictCsvs)

# %%
lstCsvNames = ["acquisitions", "additions", "companies", "investments", "rounds"]

dfAllCols = pd.DataFrame(dfsCols("", lstCsvNames, *dfAll))
dfAllCols
# Out:
#               acquisitions  additions          companies  \
# 0        company_permalink    content          permalink
# 1             company_name  month_str               name
# 2    company_category_list   year_str       homepage_url
# 3     company_country_code      value      category_list
# 4       company_state_code             funding_total_usd
# 5           company_region                        status
# 6             company_city                  country_code
# 7       acquirer_permalink                    state_code
# 8            acquirer_name                        region
# 9   acquirer_category_list                          city
# 10   acquirer_country_code                funding_rounds
# 11     acquirer_state_code                    founded_at
# 12         acquirer_region              first_funding_at
# 13           acquirer_city               last_funding_at
# 14             acquired_at
# 15          acquired_month
# 16            price_amount
# 17     price_currency_code
#
#                 investments                   rounds
# 0         company_permalink        company_permalink
# 1              company_name             company_name
# 2     company_category_list    company_category_list
# 3      company_country_code     company_country_code
# 4        company_state_code       company_state_code
# 5            company_region           company_region
# 6              company_city             company_city
# 7        investor_permalink  funding_round_permalink
# 8             investor_name       funding_round_type
# 9     investor_country_code       funding_round_code
# 10      investor_state_code                funded_at
# 11          investor_region        raised_amount_usd
# 12            investor_city
# 13  funding_round_permalink
# 14       funding_round_type
# 15       funding_round_code
# 16                funded_at
# 17        raised_amount_usd

# %%
acquis.sample(5).transpose()
# Out:
#                                                         18952  \
# company_permalink                          /organization/zvrs
# company_name                                             ZVRS
# company_category_list                                     NaN
# company_country_code                                      USA
# company_state_code                                         FL
# company_region                                          Tampa
# company_city                                       Clearwater
# acquirer_permalink      /organization/kinderhook-industries-2
# acquirer_name                           Kinderhook Industries
# acquirer_category_list                                    NaN
# acquirer_country_code                                     USA
# acquirer_state_code                                        NY
# acquirer_region                                 New York City
# acquirer_city                                        New York
# acquired_at                                          2/9/2015
# acquired_month                                        2015-02
# price_amount                                              NaN
# price_currency_code                                       USD
#
#                                                      9560   \
# company_permalink             /organization/lincoln-snacks
# company_name                                Lincoln Snacks
# company_category_list                      Specialty Foods
# company_country_code                                   USA
# company_state_code                                      NE
# company_region                                       Omaha
# company_city                                       Lincoln
# acquirer_permalink      /organization/willis-stein-partnes
# acquirer_name                       Willis Stein & Partnes
# acquirer_category_list         Business Services|Consumers
# acquirer_country_code                                  USA
# acquirer_state_code                                     IL
# acquirer_region                                    Chicago
# acquirer_city                                      Chicago
# acquired_at                                       3/2/2004
# acquired_month                                     2004-03
# price_amount                                           NaN
# price_currency_code                                    USD
#
#                                                    18148  \
# company_permalink       /organization/viztu-technologies
# company_name                          Viztu Technologies
# company_category_list                        3D|Software
# company_country_code                                 USA
# company_state_code                                    MA
# company_region                                    Boston
# company_city                                   Cambridge
# acquirer_permalink              /organization/3d-systems
# acquirer_name                                 3D Systems
# acquirer_category_list                          Software
# acquirer_country_code                                USA
# acquirer_state_code                                   SC
# acquirer_region                               SC - Other
# acquirer_city                                  Rock Hill
# acquired_at                                    7/23/2012
# acquired_month                                   2012-07
# price_amount                                         NaN
# price_currency_code                                  USD
#
#                                                                     11759  \
# company_permalink                                 /organization/numbercop
# company_name                                                    NumberCop
# company_category_list   Android|Cyber Security|iPhone|Mobile|Security|...
# company_country_code                                                  USA
# company_state_code                                                     CA
# company_region                                                SF Bay Area
# company_city                                                San Francisco
# acquirer_permalink                           /organization/whitepages-com
# acquirer_name                                                  Whitepages
# acquirer_category_list  Curated Web|Fraud Detection|Identity Managemen...
# acquirer_country_code                                                 USA
# acquirer_state_code                                                    WA
# acquirer_region                                                   Seattle
# acquirer_city                                                     Seattle
# acquired_at                                                     6/10/2015
# acquired_month                                                    2015-06
# price_amount                                                          NaN
# price_currency_code                                                   USD
#
#                                                1492
# company_permalink       /organization/asic-architect
# company_name                          ASIC Architect
# company_category_list                 Semiconductors
# company_country_code                             USA
# company_state_code                                CA
# company_region                           SF Bay Area
# company_city                             Santa Clara
# acquirer_permalink            /organization/snowbush
# acquirer_name                               Snowbush
# acquirer_category_list                Semiconductors
# acquirer_country_code                            CAN
# acquirer_state_code                               ON
# acquirer_region                              Toronto
# acquirer_city                                Toronto
# acquired_at                                7/28/2008
# acquired_month                               2008-07
# price_amount                               1500000.0
# price_currency_code                              USD

# %%
additions.sample(5).transpose()
# Out:
#                    82       702                     1800  \
# content    Acquisitions     IPOs  Rounds: private_equity
# month_str       1998-01  2013-03                 2012-03
# year_str           1998     2013                    2012
# value                 7       19                       7
#
#                              1490           1578
# content    Rounds: debt_financing  Rounds: grant
# month_str                 2014-01        2010-07
# year_str                     2014           2010
# value                         359             10

# %%
companies.sample(5).transpose()
# Out:
#                                              30132                    36514  \
# permalink           /organization/kalyan-jewellers  /organization/mobilitec
# name                              Kalyan Jewellers                Mobilitec
# homepage_url       http://www.kalyanjewellers.net/                      NaN
# category_list                              Jewelry                 Software
# funding_total_usd                        200000000                 12100000
# status                                   operating                operating
# country_code                                   IND                      USA
# state_code                                     NaN                       CA
# region                                         NaN              SF Bay Area
# city                                           NaN                San Mateo
# funding_rounds                                   1                        1
# founded_at                                1/1/1993                 1/1/2000
# first_funding_at                         8/26/2014                 2/7/2005
# last_funding_at                          8/26/2014                 2/7/2005
#
#                                               1799   \
# permalink                    /organization/affibody
# name                                       Affibody
# homepage_url                http://www.affibody.com
# category_list      Biotechnology|Health Diagnostics
# funding_total_usd                          28499283
# status                                    operating
# country_code                                    SWE
# state_code                                       26
# region                                    Stockholm
# city                                      Stockholm
# funding_rounds                                    1
# founded_at                                      NaN
# first_funding_at                          3/30/2007
# last_funding_at                           3/30/2007
#
#                                         43295                        65401
# permalink          /organization/philz-coffee  /organization/your-pet-chef
# name                             Philz Coffee                Your Pet Chef
# homepage_url           http://philzcoffee.com   http://www.yourpetchef.com
# category_list               Coffee|E-Commerce                         Pets
# funding_total_usd                    30000000                            -
# status                              operating                    operating
# country_code                              USA                          USA
# state_code                                 CA                           IL
# region                            SF Bay Area                      Chicago
# city                            San Francisco                      Chicago
# funding_rounds                              2                            1
# founded_at                           1/1/2003                     5/1/2012
# first_funding_at                     5/2/2013                   10/27/2014
# last_funding_at                     2/18/2015                   10/27/2014

# %%
invests.sample(5).transpose()
# Out:
#                                                                   116307  \
# company_permalink                                 /organization/pubmatic
# company_name                                                    PubMatic
# company_category_list                   Advertising|Marketing Automation
# company_country_code                                                 USA
# company_state_code                                                    CA
# company_region                                               SF Bay Area
# company_city                                                Redwood City
# investor_permalink                  /organization/nexus-venture-partners
# investor_name                                     Nexus Venture Partners
# investor_country_code                                                USA
# investor_state_code                                                   CA
# investor_region                                              SF Bay Area
# investor_city                                                 Menlo Park
# funding_round_permalink  /funding-round/35353560b0df2f73dc404e5d2d27844e
# funding_round_type                                               venture
# funding_round_code                                                     D
# funded_at                                                       6/6/2012
# raised_amount_usd                                             32000000.0
#
#                                                                   93248   \
# company_permalink                                 /organization/moseeker
# company_name                                                    MoSeeker
# company_category_list                      Media|Recruiting|Social Media
# company_country_code                                                 CHN
# company_state_code                                                    23
# company_region                                                       NaN
# company_city                                                         NaN
# investor_permalink                                        /person/zhu-li
# investor_name                                                     Zhu Li
# investor_country_code                                                NaN
# investor_state_code                                                  NaN
# investor_region                                                      NaN
# investor_city                                                        NaN
# funding_round_permalink  /funding-round/203442569c8c11a5c1e27dfe228996bf
# funding_round_type                                                 angel
# funding_round_code                                                   NaN
# funded_at                                                      9/30/2014
# raised_amount_usd                                               814196.0
#
#                                                                   66722   \
# company_permalink                                   /organization/hyper9
# company_name                                                      Hyper9
# company_category_list                                           Software
# company_country_code                                                 USA
# company_state_code                                                    TX
# company_region                                                    Austin
# company_city                                                      Austin
# investor_permalink                                 /organization/venrock
# investor_name                                                    Venrock
# investor_country_code                                                USA
# investor_state_code                                                   CA
# investor_region                                              SF Bay Area
# investor_city                                                  Palo Alto
# funding_round_permalink  /funding-round/eab573901af0644813963088ab00241c
# funding_round_type                                               venture
# funding_round_code                                                     B
# funded_at                                                      2/26/2009
# raised_amount_usd                                              8000000.0
#
#                                                                     15087   \
# company_permalink                         /organization/b2x-care-solutions
# company_name                                            B2X Care Solutions
# company_category_list    Customer Service|Hardware + Software|Mobile|Su...
# company_country_code                                                   DEU
# company_state_code                                                       2
# company_region                                                      Munich
# company_city                                                        Munich
# investor_permalink                             /organization/grazia-equity
# investor_name                                                Grazia Equity
# investor_country_code                                                  DEU
# investor_state_code                                                      1
# investor_region                                                  Stuttgart
# investor_city                                                    Stuttgart
# funding_round_permalink    /funding-round/83f2d9e955efdd370a22eccc6765b5d4
# funding_round_type                                          private_equity
# funding_round_code                                                     NaN
# funded_at                                                         1/1/2012
# raised_amount_usd                                                      NaN
#
#                                                                   64982
# company_permalink                               /organization/hipcricket
# company_name                                                  Hipcricket
# company_category_list     Advertising|Business Analytics|Mobile Commerce
# company_country_code                                                 USA
# company_state_code                                                    NY
# company_region                                             New York City
# company_city                                                    New York
# investor_permalink                       /organization/broadmark-capital
# investor_name                                          Broadmark Capital
# investor_country_code                                                USA
# investor_state_code                                                   WA
# investor_region                                                  Seattle
# investor_city                                                    Seattle
# funding_round_permalink  /funding-round/b07a0ba3dfba0f273445d722fe5b33ee
# funding_round_type                                               venture
# funding_round_code                                                     A
# funded_at                                                      3/22/2007
# raised_amount_usd                                              2000000.0

# %%
rounds.sample(5).transpose()
# Out:
#                                                                      90033  \
# company_permalink                                 /organization/singld-out
# company_name                                                    Singld Out
# company_category_list    Online Dating|Professional Networking|Social N...
# company_country_code                                                   USA
# company_state_code                                                      CA
# company_region                                                   San Diego
# company_city                                                     San Diego
# funding_round_permalink    /funding-round/fd82616a890814bcc867a01918e90f17
# funding_round_type                                                    seed
# funding_round_code                                                     NaN
# funded_at                                                       10/28/2014
# raised_amount_usd                                                 600000.0
#
#                                                                      47532  \
# company_permalink                                 /organization/influicity
# company_name                                                    Influicity
# company_category_list    Celebrity|Enterprise Software|Marketplaces|Med...
# company_country_code                                                   CAN
# company_state_code                                                      ON
# company_region                                                     Toronto
# company_city                                                       Toronto
# funding_round_permalink    /funding-round/16be95b50f427693f955e1d8a3974439
# funding_round_type                                                    seed
# funding_round_code                                                     NaN
# funded_at                                                         3/2/2015
# raised_amount_usd                                                      NaN
#
#                                                                    79800  \
# company_permalink                         /organization/pyxis-technology
# company_name                                            Pyxis Technology
# company_category_list                                           Software
# company_country_code                                                 USA
# company_state_code                                                    TX
# company_region                                                    Austin
# company_city                                                      Austin
# funding_round_permalink  /funding-round/a5fc767ec9bafa9bd9fb93788f56e6a7
# funding_round_type                                               venture
# funding_round_code                                                   NaN
# funded_at                                                      4/20/2010
# raised_amount_usd                                              1270000.0
#
#                                                                    43219  \
# company_permalink                         /organization/hdl-therapeutics
# company_name                                            hdl therapeutics
# company_category_list                                      Biotechnology
# company_country_code                                                 USA
# company_state_code                                                    NJ
# company_region                                                    Newark
# company_city                                                 Short Hills
# funding_round_permalink  /funding-round/3e460679694b64b5b8624c86f0700661
# funding_round_type                                               venture
# funding_round_code                                                     B
# funded_at                                                     12/31/2014
# raised_amount_usd                                              2045000.0
#
#                                                                      4401
# company_permalink                                    /organization/align-3
# company_name                                                         Align
# company_category_list    Lifestyle|Online Dating|Social Network Media|S...
# company_country_code                                                   USA
# company_state_code                                                      CA
# company_region                                                 Los Angeles
# company_city                                                   Los Angeles
# funding_round_permalink    /funding-round/1fddfe150e3c4c99986266a8af4d0ecc
# funding_round_type                                                    seed
# funding_round_code                                                     NaN
# funded_at                                                         9/1/2014
# raised_amount_usd                                                 100000.0

# %% [markdown]
# Seeing (via a dataframe) the columns in the dataframes

# %%
#getting all (unique) columns of the datasets
uniqueCols = set() #or: instead of "{}", "set()"
for ele in dfAll:
    cols = ele.columns.tolist() #".tolist()" to make it a list (side note: ".values" to make it a numpy.ndarray)
    
    uniqueCols.update(cols) #use ".add()" for elements, ".update()" for lists

# %%
#sorting the columns alphabetically
tempList = list(uniqueCols)
tempList.sort()
uniqueCols = tempList
uniqueCols
# Out:
# ['acquired_at',
#  'acquired_month',
#  'acquirer_category_list',
#  'acquirer_city',
#  'acquirer_country_code',
#  'acquirer_name',
#  'acquirer_permalink',
#  'acquirer_region',
#  'acquirer_state_code',
#  'category_list',
#  'city',
#  'company_category_list',
#  'company_city',
#  'company_country_code',
#  'company_name',
#  'company_permalink',
#  'company_region',
#  'company_state_code',
#  'content',
#  'country_code',
#  'first_funding_at',
#  'founded_at',
#  'funded_at',
#  'funding_round_code',
#  'funding_round_permalink',
#  'funding_round_type',
#  'funding_rounds',
#  'funding_total_usd',
#  'homepage_url',
#  'investor_city',
#  'investor_country_code',
#  'investor_name',
#  'investor_permalink',
#  'investor_region',
#  'investor_state_code',
#  'last_funding_at',
#  'month_str',
#  'name',
#  'permalink',
#  'price_amount',
#  'price_currency_code',
#  'raised_amount_usd',
#  'region',
#  'state_code',
#  'status',
#  'value',
#  'year_str']

# %% [markdown]
# Seeing the columns in a dataframe

# %%
# Check the first 5 rows of the data
acquis.head()
# Out:
#                                    company_permalink  \
# 0                               /organization/003-ru
# 1                      /organization/0958572-b-c-ltd
# 2                 /organization/1-800-communications
# 3                       /organization/1-800-contacts
# 4  /organization/1-844-446-4460-pogo-customer-ser...
#
#                                         company_name  \
# 0                                             003.RU
# 1                                  0958572 B.C. Ltd.
# 2                               1-800 Communications
# 3                                     1-800 Contacts
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                        company_category_list company_country_code  \
# 0  Consumer Electronics|Electronics|Internet                  RUS
# 1                                        NaN                  NaN
# 2                                        NaN                  USA
# 3                      Consumer Goods|Retail                  USA
# 4                                        NaN                  NaN
#
#   company_state_code  company_region company_city  \
# 0                 48          Moscow       Moscow
# 1                NaN             NaN          NaN
# 2                 NY     Long Island   Hicksville
# 3                 UT  Salt Lake City       Draper
# 4                NaN             NaN          NaN
#
#                                   acquirer_permalink  \
# 0                         /organization/media-saturn
# 1  /organization/atlas-intellectual-property-mana...
# 2                       /organization/carsdirect-com
# 3                /organization/thomas-h-lee-partners
# 4  /organization/pogo-customer-service-number-1-8...
#
#                                        acquirer_name  \
# 0                                       Media Saturn
# 1         ATLAS Intellectual Property Management Co.
# 2                                     CarsDirect.com
# 3                             Thomas H. Lee Partners
# 4  Games Support +1-800-311-5934 Pogo Games techn...
#
#                               acquirer_category_list acquirer_country_code  \
# 0      Enterprise Software|Media|Sales and Marketing                   ESP
# 1          Finance|FinTech|Mobile|Telecommunications                   USA
# 2                                         E-Commerce                   USA
# 3  Business Development|Impact Investing|Investme...                   USA
# 4                                                NaN                   USA
#
#   acquirer_state_code acquirer_region acquirer_city acquired_at  \
# 0                  56       Barcelona     Barcelona  2012-07-23
# 1                  WA         Seattle       Seattle  2012-02-02
# 2                  CA     Los Angeles    El Segundo  2005-06-12
# 3                  MA          Boston        Boston  2014-01-07
# 4                  NY   New York City    Mamaroneck  2001-02-02
#
#   acquired_month  price_amount price_currency_code
# 0        2012-07           NaN                 USD
# 1        2012-02     9000000.0                 USD
# 2        2005-06           NaN                 USD
# 3        2014-01           NaN                 USD
# 4        2001-02           NaN                 USD
